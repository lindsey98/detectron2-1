# %%
import seaborn as sns
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
for file in os.listdir('../saved/haha/'):
    if file.endswith('pkl'):
        with open('../saved/haha/' + file, 'rb') as handle:
            x = pickle.load(handle)
        break
